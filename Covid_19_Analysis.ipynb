# %% [markdown]
# # Import Libraries and Load Data

# %%
import pandas as pd
import numpy  as np

df= pd.read_csv('country_wise_latest.csv')

print("Initial Dataset Shape:", df.shape)
df.isnull().sum()
# Out:
# Initial Dataset Shape: (187, 15)
# Country/Region            0
# Confirmed                 0
# Deaths                    0
# Recovered                 0
# Active                    0
# New cases                 0
# New deaths                0
# New recovered             0
# Deaths / 100 Cases        0
# Recovered / 100 Cases     0
# Deaths / 100 Recovered    0
# Confirmed last week       0
# 1 week change             0
# 1 week % increase         0
# WHO Region                0
# dtype: int64

# %% [markdown]
# # Data Cleaning and Standardization

# %%
# View the standardized column names

print("Standardized Columns:\n", df.columns.tolist())
# Out:
# Standardized Columns:
#  ['Country/Region', 'Confirmed', 'Deaths', 'Recovered', 'Active', 'New cases', 'New deaths', 'New recovered', 'Deaths / 100 Cases', 'Recovered / 100 Cases', 'Deaths / 100 Recovered', 'Confirmed last week', '1 week change', '1 week % increase', 'WHO Region']

# %% [markdown]
# # Feature Engineering and Exporting Cleaned Data

# %%
# Add a custom analysis flag or feature if needed, then export to a final clean CSV for SQL
df.to_csv('covid_cleaned_final.csv', index=False)
print("Success: 'covid_cleaned_final.csv' has been created for SQL Database Import!")
# Out:
# Success: 'covid_cleaned_final.csv' has been created for SQL Database Import!
